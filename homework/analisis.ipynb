# %%
import pandas as pd

df = pd.read_csv("../files/output/solicitudes_de_credito.csv", sep=";")

df
# Out:
#             sexo tipo_de_emprendimiento          idea_negocio  \
# 0      masculino               comercio            fabrica de
# 1       femenino               servicio  recreativo educativo
# 2       femenino               comercio                tienda
# 3      masculino               comercio            variedades
# 4       femenino               comercio            fabrica de
# ...          ...                    ...                   ...
# 10201   femenino               servicio                tienda
# 10202  masculino           agropecuaria       comidas rapidas
# 10203  masculino               comercio     fabrica de arepas
# 10204   femenino               comercio            variedades
# 10205   femenino               servicio       cafe e internet
#
#                        barrio  estrato  comuna_ciudadano fecha_de_beneficio  \
# 0                       prado        3                10         13/07/2018
# ...

# %%
df.barrio.value_counts()
# Out:
# barrio
# robledo                   990
# manrique central no. 1    483
# san javier no.1           423
# aranjuez                  383
# belen                     376
#                          ...
# villa flora                 1
# mirador del doce            1
# suburbano barro             1
# el estadio                  1
# el llano                    1
# Name: count, Length: 225, dtype: int64

# %%
original = pd.read_csv("../files/input/solicitudes_de_credito.csv", sep=";")

original.barrio.value_counts()
# Out:
# barrio
# robledo                   1000
# manrique central no. 1     475
# san javier no.1            416
# aranjuez                   382
# belen                      381
#                           ...
# los angeles                  1
# centro-admtivo               1
# Villa Del Socorro            1
# Bombona No. 1                1
# fatima                       1
# Name: count, Length: 430, dtype: int64

# %%
df[df["barrio"] == "ANTONIO NARI¿O"]
# Out:
# Empty DataFrame
# Columns: [sexo, tipo_de_emprendimiento, idea_negocio, barrio, estrato, comuna_ciudadano, fecha_de_beneficio, monto_del_credito, línea_credito]
# Index: []

# %%
import re


s = ["$ 7,377,000.00", "3000000"]

patron = r"[0-9]+"


for cadena in s:
    coincidencia = re.findall(patron, cadena)
    numero = "".join(coincidencia)
    
    print(numero)
# Out:
# 737700000
# 3000000
